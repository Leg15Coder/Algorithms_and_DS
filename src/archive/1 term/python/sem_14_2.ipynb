# %% [markdown]
# # Занятие 14
#
# Библиотека sqlite3 (продолжение). Типы операторов объединений таблиц.
# Написание сложных запросов к базам данных при помощи библиотеки sqlite3.

# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# Создать базу данных в Python с помощью SQLite можно несколькими способами. Для этого используется объект Connection, который и представляет собой базу. Он создается с помощью функции connect().
#
# Создадим файл .db, поскольку это стандартный способ управления базой SQLite. Файл будет называться orders.db. За соединение будет отвечать переменная conn.

# %% [raw]
# conn = sqlite3.connect(r'ПУТЬ-К-ПАПКИ/orders.db')

# %% [markdown]
# Перед строкой с путем стоит символ «r», так как речь идет о «сырой» строке, где символы «/» не отвечают за экранирование.

# %%
conn = sqlite3.connect(':memory:')

# %%
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
connection = create_connection("SQL_s_15_03_24.db")
# Out:
# Connection to SQLite DB successful

# %% [markdown]
# После создания объекта соединения с базой данных нужно создать объект cursor. Он позволяет делать SQL-запросы к базе. Используем переменную cur для хранения объекта:

# %%
cur = connection.cursor()

# %% [markdown]
# Выполняем SQL-запрос используя метод .execute():

# %%
cur.execute("""CREATE TABLE IF NOT EXISTS users(
   userid INT PRIMARY KEY,
   fname TEXT,
   lname TEXT,
   gender TEXT);
""")
conn.commit()

# %%
cur.execute("""CREATE TABLE IF NOT EXISTS orders(
   orderid INT PRIMARY KEY,
   date TEXT,
   userid TEXT,
   total TEXT);
""")
conn.commit()

# %% [markdown]
# Теперь в базе данных две таблицы.

# %%
users = [('00003', 'Peter', 'Parker', 'Male'), ('00004', 'Bruce', 'Wayne', 'male')]

# %% [markdown]
# SQLite ожидает получить значения в формате кортежа. Однако в переменной может быть и список с набором кортежей. Таким образом можно добавить несколько пользователей. В этом случае нужно использовать метод .executemany().

# %%
cur.executemany("INSERT INTO users VALUES(?, ?, ?, ?);", users)
conn.commit()

# %%
customers = [
  ('00005', 'Stephanie', 'Stewart', 'female'), ('00006', 'Sincere', 'Sherman', 'female'), ('00007', 'Sidney', 'Horn', 'male'), 
  ('00008', 'Litzy', 'Yates', 'female'), ('00009', 'Jaxon', 'Mills', 'male'), ('00010', 'Paul', 'Richard', 'male'), 
  ('00011', 'Kamari', 'Holden', 'female'), ('00012', 'Gaige', 'Summers', 'female'), ('00013', 'Andrea', 'Snow', 'female'), 
  ('00014', 'Angelica', 'Barnes', 'female'), ('00015', 'Leah', 'Pitts', 'female'), ('00016', 'Dillan', 'Olsen', 'male'), 
  ('00017', 'Joe', 'Walsh', 'male'), ('00018', 'Reagan', 'Cooper', 'male'), ('00019', 'Aubree', 'Hogan', 'female'), 
  ('00020', 'Avery', 'Floyd', 'male'), ('00021', 'Elianna', 'Simmons', 'female'), ('00022', 'Rodney', 'Stout', 'male'), 
  ('00023', 'Elaine', 'Mcintosh', 'female'), ('00024', 'Myla', 'Mckenzie', 'female'), ('00025', 'Alijah', 'Horn', 'female'),
  ('00026', 'Rohan', 'Peterson', 'male'), ('00027', 'Irene', 'Walters', 'female'), ('00028', 'Lilia', 'Sellers', 'female'), 
  ('00029', 'Perla', 'Jefferson', 'female'), ('00030', 'Ashley', 'Klein', 'female')
]
orders = [
  ('00001', '2020-01-01', '00025', '178'), ('00002', '2020-01-03', '00025', '39'), ('00003', '2020-01-07', '00016', '153'), 
  ('00004', '2020-01-10', '00015', '110'), ('00005', '2020-01-11', '00024', '219'), ('00006', '2020-01-12', '00029', '37'), 
  ('00007', '2020-01-14', '00028', '227'), ('00008', '2020-01-18', '00010', '232'), ('00009', '2020-01-22', '00016', '236'), 
  ('00010', '2020-01-26', '00017', '116'), ('00011', '2020-01-28', '00028', '221'), ('00012', '2020-01-31', '00021', '238'), 
  ('00013', '2020-02-02', '00015', '177'), ('00014', '2020-02-05', '00025', '76'), ('00015', '2020-02-08', '00022', '245'), 
  ('00016', '2020-02-12', '00008', '180'), ('00017', '2020-02-14', '00020', '190'), ('00018', '2020-02-18', '00030', '166'),
  ('00019', '2020-02-22', '00002', '168'), ('00020', '2020-02-26', '00021', '174'), ('00021', '2020-02-29', '00017', '126'), 
  ('00022', '2020-03-02', '00019', '211'), ('00023', '2020-03-05', '00030', '144'), ('00024', '2020-03-09', '00012', '112'), 
  ('00025', '2020-03-10', '00006', '45'), ('00026', '2020-03-11', '00004', '200'), ('00027', '2020-03-14', '00015', '226'), 
  ('00028', '2020-03-17', '00030', '189'), ('00029', '2020-03-20', '00004', '152'), ('00030', '2020-03-22', '00026', '239'), 
  ('00031', '2020-03-23', '00012', '135'), ('00032', '2020-03-24', '00013', '211'), ('00033', '2020-03-27', '00030', '226'), 
  ('00034', '2020-03-28', '00007', '173'), ('00035', '2020-03-30', '00010', '144'), ('00036', '2020-04-01', '00017', '185'), 
  ('00037', '2020-04-03', '00009', '95'), ('00038', '2020-04-06', '00009', '138'), ('00039', '2020-04-10', '00025', '223'), 
  ('00040', '2020-04-12', '00019', '118'), ('00041', '2020-04-15', '00024', '132'), ('00042', '2020-04-18', '00008', '238'), 
  ('00043', '2020-04-21', '00003', '50'), ('00044', '2020-04-25', '00019', '98'), ('00045', '2020-04-26', '00017', '167'), 
  ('00046', '2020-04-28', '00009', '215'), ('00047', '2020-05-01', '00014', '142'), ('00048', '2020-05-05', '00022', '173'),
  ('00049', '2020-05-06', '00015', '80'), ('00050', '2020-05-07', '00017', '37'), ('00051', '2020-05-08', '00002', '36'), 
  ('00052', '2020-05-10', '00022', '65'), ('00053', '2020-05-14', '00019', '110'), ('00054', '2020-05-18', '00017', '36'), 
  ('00055', '2020-05-21', '00008', '163'), ('00056', '2020-05-24', '00024', '91'), ('00057', '2020-05-26', '00028', '154'), 
  ('00058', '2020-05-30', '00022', '130'), ('00059', '2020-05-31', '00017', '119'), ('00060', '2020-06-01', '00024', '137'), 
  ('00061', '2020-06-03', '00017', '206'), ('00062', '2020-06-04', '00013', '100'), ('00063', '2020-06-05', '00021', '187'), 
  ('00064', '2020-06-09', '00025', '170'), ('00065', '2020-06-11', '00011', '149'), ('00066', '2020-06-12', '00007', '195'), 
  ('00067', '2020-06-14', '00015', '30'), ('00068', '2020-06-16', '00002', '246'), ('00069', '2020-06-20', '00028', '163'),
  ('00070', '2020-06-22', '00005', '184'), ('00071', '2020-06-23', '00022', '68'), ('00072', '2020-06-27', '00013', '92'), 
  ('00073', '2020-06-30', '00022', '149'), ('00074', '2020-07-04', '00002', '65'), ('00075', '2020-07-05', '00017', '88'), 
  ('00076', '2020-07-09', '00007', '156'), ('00077', '2020-07-13', '00010', '26'), ('00078', '2020-07-16', '00008', '55'), 
  ('00079', '2020-07-20', '00019', '81'), ('00080', '2020-07-22', '00011', '78'), ('00081', '2020-07-23', '00026', '166'), 
  ('00082', '2020-07-27', '00014', '65'), ('00083', '2020-07-30', '00021', '205'), ('00084', '2020-08-01', '00026', '140'), 
  ('00085', '2020-08-05', '00006', '236'), ('00086', '2020-08-06', '00021', '208'), ('00087', '2020-08-07', '00021', '169'), 
  ('00088', '2020-08-08', '00004', '157'), ('00089', '2020-08-11', '00017', '71'), ('00090', '2020-08-13', '00025', '89'), 
  ('00091', '2020-08-16', '00014', '249'), ('00092', '2020-08-18', '00012', '59'), ('00093', '2020-08-19', '00013', '121'),
  ('00094', '2020-08-20', '00025', '179'), ('00095', '2020-08-22', '00017', '208'), ('00096', '2020-08-26', '00024', '217'), 
  ('00097', '2020-08-28', '00004', '206'), ('00098', '2020-08-30', '00017', '114'), ('00099', '2020-08-31', '00017', '169'), 
  ('00100', '2020-09-02', '00022', '226')
]

# %%
cur.executemany("INSERT INTO users VALUES(?, ?, ?, ?);", customers)
cur.executemany("INSERT INTO orders VALUES(?, ?, ?, ?);", orders)
conn.commit()

# %% [markdown]
# Функции fetchone() используется для получения только одного результата, возвращаемого SQL-запросом.

# %%
cur.execute("SELECT * FROM users;")
one_result = cur.fetchone()
print(one_result)
# Out:
# (3, 'Peter', 'Parker', 'Male')

# %% [markdown]
# Функция fetchmany() позволяет вернуть несколько строк результата, возвращаемого SQL-запросом.

# %%
cur.execute("SELECT * FROM users;")
three_results = cur.fetchmany(3)
print(three_results)
# Out:
# [(3, 'Peter', 'Parker', 'Male'), (4, 'Bruce', 'Wayne', 'male'), (5, 'Stephanie', 'Stewart', 'female')]

# %% [markdown]
# Функция fetchall() используется для получения всех результатов.

# %%
cur.execute("SELECT * FROM users;")
all_results = cur.fetchall()
print(all_results)
# Out:
# [(3, 'Peter', 'Parker', 'Male'), (4, 'Bruce', 'Wayne', 'male'), (5, 'Stephanie', 'Stewart', 'female'), (6, 'Sincere', 'Sherman', 'female'), (7, 'Sidney', 'Horn', 'male'), (8, 'Litzy', 'Yates', 'female'), (9, 'Jaxon', 'Mills', 'male'), (10, 'Paul', 'Richard', 'male'), (11, 'Kamari', 'Holden', 'female'), (12, 'Gaige', 'Summers', 'female'), (13, 'Andrea', 'Snow', 'female'), (14, 'Angelica', 'Barnes', 'female'), (15, 'Leah', 'Pitts', 'female'), (16, 'Dillan', 'Olsen', 'male'), (17, 'Joe', 'Walsh', 'male'), (18, 'Reagan', 'Cooper', 'male'), (19, 'Aubree', 'Hogan', 'female'), (20, 'Avery', 'Floyd', 'male'), (21, 'Elianna', 'Simmons', 'female'), (22, 'Rodney', 'Stout', 'male'), (23, 'Elaine', 'Mcintosh', 'female'), (24, 'Myla', 'Mckenzie', 'female'), (25, 'Alijah', 'Horn', 'female'), (26, 'Rohan', 'Peterson', 'male'), (27, 'Irene', 'Walters', 'female'), (28, 'Lilia', 'Sellers', 'female'), (29, 'Perla', 'Jefferson', 'female'), (30, 'Ashley', 'Klein', 'female')]

# %% [markdown]
# ## Объединение таблиц
#
# **INNER JOIN** - внутреннее соединение. В результате остаются только те строки, для которых нашлось соответствие. До сих пор мы использовали только этот тип соединений.
#
# **LEFT JOIN** - левое внешнее соединение. Работает как JOIN, но если для строки таблицы, находящейся по левую сторону ключевого слова LEFT JOIN, не нашлось ни одной строки в таблице, находящейся по правую сторону LEFT JOIN, то строка все равно добавляется в результат, а значения столбцов правой таблицы равны null.
#
# **RIGHT JOIN** - правое внешнее соединение. Работает как JOIN, но если для строки таблицы, находящейся по правую сторону ключевого слова RIGHT JOIN, не нашлось ни одной строки в таблице, находящейся по левую сторону RIGHT JOIN, то строка все равно добавляется в результат, а значения столбцов левой таблицы равны null.
#
# **FULL JOIN** - полное внешнее соединение. Если для какой-либо из таблиц не нашлось строки в другой таблице, то строка все равно попадает в результат, а значения столбцов другой таблицы равны null.
#
# **CROSS JOIN** - перекрестное (или декартово) произведение. Каждая строка одной таблицы соединяется с каждой строкой второй таблицы, давая тем самым в результате все возможные сочетания строк двух таблиц. Аналогичного результата можно достичь просто перечислив таблицы в FROM через запятую.

# %%
cur.execute("""SELECT *, users.fname, users.lname FROM orders
    LEFT JOIN users ON users.userid=orders.userid;""")
print(cur.fetchall())
# Out:
# [(1, '2020-01-01', '00025', '178', 25, 'Alijah', 'Horn', 'female', 'Alijah', 'Horn'), (2, '2020-01-03', '00025', '39', 25, 'Alijah', 'Horn', 'female', 'Alijah', 'Horn'), (3, '2020-01-07', '00016', '153', 16, 'Dillan', 'Olsen', 'male', 'Dillan', 'Olsen'), (4, '2020-01-10', '00015', '110', 15, 'Leah', 'Pitts', 'female', 'Leah', 'Pitts'), (5, '2020-01-11', '00024', '219', 24, 'Myla', 'Mckenzie', 'female', 'Myla', 'Mckenzie'), (6, '2020-01-12', '00029', '37', 29, 'Perla', 'Jefferson', 'female', 'Perla', 'Jefferson'), (7, '2020-01-14', '00028', '227', 28, 'Lilia', 'Sellers', 'female', 'Lilia', 'Sellers'), (8, '2020-01-18', '00010', '232', 10, 'Paul', 'Richard', 'male', 'Paul', 'Richard'), (9, '2020-01-22', '00016', '236', 16, 'Dillan', 'Olsen', 'male', 'Dillan', 'Olsen'), (10, '2020-01-26', '00017', '116', 17, 'Joe', 'Walsh', 'male', 'Joe', 'Walsh'), (11, '2020-01-28', '00028', '221', 28, 'Lilia', 'Sellers', 'female', 'Lilia', 'Sellers'), (12, '2020-01-31', '00021', '238', 21, 'Elianna', 'Simmons', 'female', 'Elianna', 'Simmons'), (13, '2020-02-02', '00015', '177', 15, 'Leah', 'Pitts', 'female', 'Leah', 'Pitts'), (14, '2020-02-05', '00025', '76', 25, 'Alijah', 'Horn', 'female', 'Alijah', 'Horn'), (15, '2020-02-08', '00022', '245', 22, 'Rodney', 'Stout', 'male', 'Rodney', 'Stout'), (16, '2020-02-12', '00008', '180', 8, 'Litzy', 'Yates', 'female', 'Litzy', 'Yates'), (17, '2020-02-14', '00020', '190', 20, 'Avery', 'Floyd', 'male', 'Avery', 'Floyd'), (18, '2020-02-18', '00030', '166', 30, 'Ashley', 'Klein', 'female', 'Ashley', 'Klein'), (19, '2020-02-22', '00002', '168', None, None, None, None, None, None), (20, '2020-02-26', '00021', '174', 21, 'Elianna', 'Simmons', 'female', 'Elianna', 'Simmons'), (21, '2020-02-29', '00017', '126', 17, 'Joe', 'Walsh', 'male', 'Joe', 'Walsh'), (22, '2020-03-02', '00019', '211', 19, 'Aubree', 'Hogan', 'female', 'Aubree', 'Hogan'), (23, '2020-03-05', '00030', '144', 30, 'Ashley', 'Klein', 'female', 'Ashley', 'Klein'), (24, '2020-03-09', '00012', '112', 12, 'Gaige', 'Summers', 'female', 'Gaige', 'Summers'), (25, '2020-03-10', '00006', '45', 6, 'Sincere', 'Sherman', 'female', 'Sincere', 'Sherman'), (26, '2020-03-11', '00004', '200', 4, 'Bruce', 'Wayne', 'male', 'Bruce', 'Wayne'), (27, '2020-03-14', '00015', '226', 15, 'Leah', 'Pitts', 'female', 'Leah', 'Pitts'), (28, '2020-03-17', '00030', '189', 30, 'Ashley', 'Klein', 'female', 'Ashley', 'Klein'), (29, '2020-03-20', '00004', '152', 4, 'Bruce', 'Wayne', 'male', 'Bruce', 'Wayne'), (30, '2020-03-22', '00026', '239', 26, 'Rohan', 'Peterson', 'male', 'Rohan', 'Peterson'), (31, '2020-03-23', '00012', '135', 12, 'Gaige', 'Summers', 'female', 'Gaige', 'Summers'), (32, '2020-03-24', '00013', '211', 13, 'Andrea', 'Snow', 'female', 'Andrea', 'Snow'), (33, '2020-03-27', '00030', '226', 30, 'Ashley', 'Klein', 'female', 'Ashley', 'Klein'), (34, '2020-03-28', '00007', '173', 7, 'Sidney', 'Horn', 'male', 'Sidney', 'Horn'), (35, '2020-03-30', '00010', '144', 10, 'Paul', 'Richard', 'male', 'Paul', 'Richard'), (36, '2020-04-01', '00017', '185', 17, 'Joe', 'Walsh', 'male', 'Joe', 'Walsh'), (37, '2020-04-03', '00009', '95', 9, 'Jaxon', 'Mills', 'male', 'Jaxon', 'Mills'), (38, '2020-04-06', '00009', '138', 9, 'Jaxon', 'Mills', 'male', 'Jaxon', 'Mills'), (39, '2020-04-10', '00025', '223', 25, 'Alijah', 'Horn', 'female', 'Alijah', 'Horn'), (40, '2020-04-12', '00019', '118', 19, 'Aubree', 'Hogan', 'female', 'Aubree', 'Hogan'), (41, '2020-04-15', '00024', '132', 24, 'Myla', 'Mckenzie', 'female', 'Myla', 'Mckenzie'), (42, '2020-04-18', '00008', '238', 8, 'Litzy', 'Yates', 'female', 'Litzy', 'Yates'), (43, '2020-04-21', '00003', '50', 3, 'Peter', 'Parker', 'Male', 'Peter', 'Parker'), (44, '2020-04-25', '00019', '98', 19, 'Aubree', 'Hogan', 'female', 'Aubree', 'Hogan'), (45, '2020-04-26', '00017', '167', 17, 'Joe', 'Walsh', 'male', 'Joe', 'Walsh'), (46, '2020-04-28', '00009', '215', 9, 'Jaxon', 'Mills', 'male', 'Jaxon', 'Mills'), (47, '2020-05-01', '00014', '142', 14, 'Angelica', 'B ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///SQL_s5.db', echo = False)

# %% [markdown]
# Метод .to_sql() записывает записи, хранящиеся в DataFrame, в базу данных SQL. Поддерживаются базы данных, поддерживаемые SQLAlchemy. Таблицы могут быть заново созданы, добавлены или перезаписаны.
#
# Наиболее часто используемые параметры метода to_sql:
#
# **name**: string
# Имя таблицы SQL.
#
# **con**: sqlalchemy.engine.Engine или sqlite3.Connection
# Использование SQLAlchemy позволяет использовать любую БД, поддерживаемую этой библиотекой.
#
# **schema**: string, optional
# Укажите схему (если это поддерживает база данных). Если схема не указана, то будет использована схема по-умолчанию.
#
# **if_exists**: {‘fail’, ‘replace’, ‘append’}, default ‘fail’
# Параметр описывает поведение, если таблица уже существует.
#
# fail: вызвать ошибку ValueError.
#
# replace: Drop table перед вставкой новых значений.
#
# append: вставить новые значения в существующую таблицу.
#
# **index**: bool, по-умолчанию True
# Запишет индекс DataFrame в виде столбца. Использует index_label в качестве имени столбца в таблице.
#
# **chunksize**: int, необязательный параметр
# Строки будут записаны партиями заданного размера за раз. По-умолчанию строки пишутся одновременно.
#
# **dtype**: dict, необязательный параметр
# Указание типа данных для столбцов. Ключи должны быть именами столбцов, а значения — типами или строками.
#
# **method**: {None, 'multi', callable}, по-умолчанию None
# Контролирует SQL Insert
#
# None: используется стандартный SQL INSERT (по одному на строку).
#
# 'multi': передать несколько значений в одном INSERT.
#
# callable: вызывается с подписью (pd_table, conn, keys, data_iter).

# %%
d = {'x': [1, 2, 3], 'y': np.array([2, 4, 8]), 'z': 100}

df1 = pd.DataFrame(d)

# %%
df1.to_sql('xyz', connection, if_exists='replace', index=False)
# Out:
# 3

# %%
df = pd.read_csv('InternationalStudentsUniversityofIdaho.csv')

# %%
df.to_sql('Students', connection, if_exists='replace', index=False)
# Out:
# 48

# %%
df.head()
# Out:
#     LevelOfStudy    StudyDurationUI                            HomeRegion  \
# 0       Graduate        1 to 2 years                           South Asia
# 1  Undergraduate  Less than 6 months                           South Asia
# 2       Graduate        1 to 2 years  Middle East and North Africa (MENA)
# 3       Graduate        2 to 3 years                           South Asia
# 4       Graduate   More than 3 years                           South Asia
#
#           CGPA                FundingSource CampusParticipation  \
# 0  3.50 - 4.00                    GRA / GTA               Often
# 1  3.50 - 4.00  Family support, Scholarship               Often
# 2  3.50 - 4.00                  Scholarship               Often
# 3  3.50 - 4.00                    GRA / GTA           Sometimes
# 4  3.00 - 3.49                    GRA / GTA           Sometimes
#
#   FriendshipEase                                 FriendsComposition  \
# 0       Moderate  Mostly students from my subcontinent but diffe...
# 1       Moderate                             A mix of all the above
# 2       Moderate      Mostly students from my own community/country
# 3           Easy                             A mix of all the above
# 4       Moderate  Mostly students from my subcontinent but diffe...
#
#                                 FriendshipPreference InterestNewFriends  ...  \
# 0  No preference, I'm open to making friends from...                Yes  ...
# 1    Students from various international backgrounds                Yes  ...
# 2    Students from various international backgrounds                Yes  ...
# 3  No preference, I'm open to making friends from...                Yes  ...
# 4    Students from various international backgrounds                Yes  ...
#
#   CulturalAdjustmentChallenge FinancialStressFrequency  \
# 0      Not challenging at all                   Always
# 1        Slightly challenging                Sometimes
# 2      Moderately challenging                   Always
# 3      Moderately challenging                Sometimes
# 4      Moderately challenging                   Always
#
#                            WorkStudyBalance     TuitionFeeConcern  \
# 0                    Moderately challenging    Slightly concerned
# 1  Not applicable (I do not work part-time)  Moderately concerned
# 2                      Slightly challenging   Extremely concerned
# 3  Not applicable (I do not work part-time)   Extremely concerned
# 4  Not applicable (I do not work part-time)    Slightly concerned
#
#   FinancialSupportSatisfaction FinancialWorriesImpact  ConsideredTransferring  \
# 0                    Satisfied                Slightly                     No
# 1                      Neutral                 Neutral                    Yes
# 2                  Unsatisfied                 Greatly                    Yes
# 3                  Unsatisfied                 Greatly                     No
# 4                  Unsatisfied                Slightly                     No
#
#      ReasonsForTransferring  \
# 0         Research Pressure
# 1         Financial reasons
# 2         Financial reasons
# 3  Academic dissatisfaction
# 4                       NaN
#
#                                          StayFactors AcademicExperienceRating
# 0  Improved academic experience, Financial suppor...                     Good
# 1  Improved academic experience, Stronger social ...                     Good
# 2                 Adaptation to cultural environment                     Good
# 3                       Improved academic experience                  Average
# 4                     Financial support/scholarships                     Good
#
# [5 rows x 28 columns]

# %%
query = '''SELECT * FROM Students
        '''
db = pd.read_sql_query(sql = query, con = connection)
db
# Out:
#      LevelOfStudy                         StudyDurationUI   \
# 0        Graduate                             1 to 2 years
# 1   Undergraduate                       Less than 6 months
# 2        Graduate                             1 to 2 years
# 3        Graduate                             2 to 3 years
# 4        Graduate                        More than 3 years
# 5       Graduated                                Graduated
# 6        Graduate                             1 to 2 years
# 7        Graduate                             1 to 2 years
# 8   Undergraduate                       6 months to 1 year
# 9   Undergraduate                       Less than 6 months
# 10       Graduate                       6 months to 1 year
# 11  Undergraduate                       Less than 6 months
# 12       Graduate                       Less than 6 months
# 13       Graduate                       6 months to 1 year
# 14       Graduate                             2 to 3 years
# 15  Undergraduate                       Less than 6 months
# 16       Graduate                             1 to 2 years
# 17  Undergraduate                             1 to 2 years
# 18       Graduate                        More than 3 years
# 19  Undergraduate                             1 to 2 years
# 20  Undergraduate                             1 to 2 years
# 21  Undergraduate                             1 to 2 years
# 22  Undergraduate                             1 to 2 years
# 23  Undergraduate                       6 months to 1 year
# 24       Graduate                             1 to 2 years
# 25  Undergraduate                             2 to 3 years
# 26  Undergraduate                       Less than 6 months
# 27  Undergraduate                       Less than 6 months
# 28  Undergraduate  Transfer (Uidaho to Another University)
# 29       Graduate                             1 to 2 years
# 30  Undergraduate                       Less than 6 months
# 31       Graduate                             1 to 2 years
# 32  Undergraduate  Transfer (Uidaho to Another University)
# 33  Undergraduate                       Less than 6 months
# 34       Graduate                       6 months to 1 year
# 35  Undergraduate                             1 to 2 years
# 36  Undergraduate                       6 months to 1 year
# 37       Graduate                             2 to 3 years
# 38  Undergraduate  Transfer (Uidaho to Another University)
# 39       Graduate                             1 to 2 years
# 40  Undergraduate                             1 to 2 years
# 41  Undergraduate                        More than 3 years
# 42  Undergraduate                       6 months to 1 year
# 43  Undergraduate                       Less than 6 months
# 44       Graduate                             1 to 2 years
# 45       Graduate                             1 to 2 years
# 46       Graduate                             1 to 2 years
# 47       Graduate                             2 to 3 years
#
#                              HomeRegion         CGPA  \
# 0                            South Asia  3.50 - 4.00
# 1                            South Asia  3.50 - 4.00
# 2   Middle East and North Africa (MENA)  3.50 - 4.00
# 3                            South Asia  3.50 - 4.00
# 4                            South Asia  3.00 - 3.49
# 5                            South Asia  3.50 - 4.00
# 6                            South Asia  3.50 - 4.00
# 7                            South Asia  3.50 - 4.00
# 8                        Southeast Asia  3.50 - 4.00
# 9                            South Asia  3.50 - 4.00
# 10                       Southeast Asia  3.50 - 4.00
# 11                           South Asia  3.00 - 3.49
# 12                           South Asia  3.50 - 4.00
# 13                           South Asia  3.50 - 4.00
# 14                            East Asia  3.00 - 3.49
# 15                           South Asia  3.50 - 4.00
# 16                           South Asia  3.50 - 4.00
# 17                       Southeast Asia  3.00 - 3.49
# 18                           South Asia  3.50 - 4.00
# 19                       Southeast Asia  3.00 - 3.49
# 20                           South Asia  3.00 - 3.49
# 21                           South Asia  2.50 - 2.99
# 22                           South Asia   2.0 - 2.49
# 23                           South Asia  3.00 - 3.49
# 24                           South Asia  3.50 - 4.00
# 25                           South Asia  3.50 - 4.00
# 26                           South Asia  3.50 - 4.00
# 27                            East Asia    Below 1.0
# 28                           South Asia  3.00 - 3.49
# 29                           South Asia  3.50 - 4.00
# 30                           South Asia  3.50 - 4.00
# 31                            East Asia  3.50 - 4.00
# 32                           South Asia  2.50 - 2.99
# 33                           South Asia  3.50 - 4.00
# 34                           South Asia  3.00 - 3.49
# 35                            East Asia  3.50 - 4.00
# 36                           South Asia   2.0 - 2.49
# 37                            East Asia  3.50 - 4.00
# 38                            East Asia  3.00 - 3.49
# 39                   Sub-Saharan Africa  3.50 - 4.00
# 40                               Europe  3.50 - 4.00
# 41                   Sub-Saharan Africa  3.00 - 3.49
# 42                   Sub-Saharan Africa  2.50 - 2.99
# 43                               Europe  3.50 - 4.00
# 44  Middle East and North Africa (MENA)  3.50 - 4.00
# 45                            East Asia  3.50 - 4.00
# 46                               Europe  3.50 - 4.00
# 47                         Central Asia  3.00 - 3.49
#
#                                         FundingSource CampusParticipation  \
# 0                                           GRA / GTA               Often
# 1                         Family support, Scholarship               Often
# 2                                         Scholarship               Often
# 3                                           GRA / GTA           Sometimes
# 4                                           GRA / GTA           Sometimes
# 5                                           GRA / GTA           Sometimes
# 6                                           GRA / GTA           Sometimes
# 7                                           GRA / GTA           Sometimes
# 8                           Part-time job (On-campus)               Often
# 9                                      Family support               Often
# 10                                          GRA / GTA           Sometimes
# 11                   Personal savings, Family support              Always
# 12                                          GRA / GTA           Sometimes
# 13                                          GRA / GTA           Sometimes
# 14                                          GRA / GTA           Sometimes
# 15                                     Family support              Always
# 16                                          GRA / GTA           Sometimes
# 17             Scholarship, Part-time job (On-campus)           Sometimes
# 18                                          GRA / GTA               Often
# 19                        Family support, Scholarship           Sometimes
# 20          Family support, Part-time job (On-campus)           Sometimes
# 21          Family support, Part-time job (On-campus)               Never
# 22  Personal savings, Scholarship, Part-time job (...              Always
# 23                        Family support, Scholarship           Sometimes
# 24                                          GRA / GTA           Sometimes
# 25          Family support, Part-time job (On-campus)              Always
# 26                                     Family support               Often
# 27      Personal savings, Family support, Scholarship           Sometimes
# 28  Family support, Scholarship, Part-time job (On...              Always
# 29                                          GRA / GTA               Often
# 30  Family support, Scholarship, Part-time job (On...               Often
# 31                                          GRA / GTA           Sometimes
# 32          Family support, Part-time job (On-campus)               Often
# 33                        Family support, Scholarship           Sometimes
# 34                                          GRA / GTA               Never
# 35  Personal savings, Scholarship, Part-time job (...               Never
# 36  Family support, Scholarship, Part-time job (On...               Often
# 37                                          GRA / GTA           Sometimes
# 38                        Family support, Scholarship               Often
# 39                                          GRA / GTA           Sometimes
# 40  Personal savings, Family support, Scholarship,...           Sometimes
# 41             Scholarship, Part-time job (On-campus)               Often
# 42  Personal savings, Scholarship, Part-time job (...           Sometimes
# 43          Family support, Part-time job (On-campus)           Sometimes
# 44                                          GRA / GTA               Never
# 45                             GRA / GTA, Scholarship               Never
# 46                                          GRA / GTA               Never
# 47                                          GRA / GTA           Sometimes
#
#    FriendshipEase                                 FriendsComposition  \
# 0        Moderate  Mostly students from my subcontinent but diffe...
# 1        Moderate                             A mix of all the above
# 2        Moderate      Mostly students from my own community/country
# 3            Easy                             A mix of all the above
# 4        Moderate  Mostly students from my subcontinent but diffe...
# 5        Moderate  Mostly international students from various cou...
# 6        Moderate      Mostly students from my own community/country
# 7        Moderate  Mostly students from my subcontinent but diffe...
# 8            Easy                             A mix of all the above
# 9        Moderate  Mostly students from my subcontinent but diffe...
# 10       Moderate                             A mix of all the above
# 11           Easy                             A mix of all the above
# 12       Moderate      Mostly students from my own community/country
# 13       Moderate      Mostly students from my own community/country
# 14       Moderate                             A mix of all the above
# 15       Moderate  Mostly international students from various cou...
# 16       Moderate  Mostly students from my subcontinent but diffe...
# 17       Moderate      Mostly students from my own community/country
# 18       Moderate  Mostly students from my subcontinent but diffe...
# 19       Moderate      Mostly students from my own community/country
# 20           Easy                             A mix of all the above
# 21      Difficult      Mostly students from my own community/country
# 22       Moderate                             A mix of all the above
# 23       Moderate  Mostly students from my subcontinent but diffe...
# 24       Moderate                             A mix of all the above
# 25      Difficult                             A mix of all the above
# 26           Easy                             A mix of all the above
# 27       Moderate      Mostly students from my own community/country
# 28           Easy                             A mix of all the above
# 29       Moderate  Mostly students from my subcontinent but diffe...
# 30       Moderate                             A mix of all the above
# 31      Difficult      Mostly students from my own community/country
# 32           Easy  Mostly students from my subcontinent but diffe...
# 33       Moderate      Mostly students from my own community/country
# 34       Moderate      Mostly students from my own community/country
# 35       Moderate                             A mix of all the above
# 36           Easy  Mostly students from my subcontinent but diffe...
# 37       Moderate      Mostly students from my own community/country
# 38       Moderate      Mostly students from my own community/country
# 39      Difficult      Mostly students from my own community/country
# 40       Moderate  Mostly international students from various cou...
# 41       Moderate  Mostly students from my subcontinent but diffe...
# 42      Difficult      Mostly students from my own community/country
# 43       Moderate  Mostly international students from various cou...
# 44      Difficult      Mostly students from my own community/country
# 45      Difficult      Mostly students from my own community/country
# 46       Moderate  Mostly international students from various cou...
# 47       Moderate      Mostly students from my own community/country
#
#                                  FriendshipPreference InterestNewFriends  ...  \
# 0   No preference, I'm open to making friends from...                Yes  ...
# 1     Students from various international backgrounds                Yes  ...
# 2     Students from various international backgrounds                Yes  ...
# 3   No preference, I'm open to making friends from...                Yes  ...
# 4     Students from various international backgrounds                Yes  ...
# 5   No preference, I'm open to making friends from...                Yes  ...
# 6     Students from various international backgrounds                Yes  ...
# 7   No preference, I'm open to making friends from...                 No  ...
# 8   No preference, I'm open to making friends from...                Yes  ...
# 9     Students from various international backgrounds                Yes  ...
# 10  No preference, I'm open to making friends from...                Yes  ...
# 11  No preference, I'm open to making friends from...                Yes  ...
# 12    Students from various international backgrounds                Yes  ...
# 13  No preference, I'm open to making friends from...                Yes  ...
# 14  No preference, I'm open to making friends from...                 No  ...
# 15  No preference, I'm open to making friends from...                Yes  ...
# 16  No preference, I'm open to making friends from...                Yes  ...
# 17  No preference, I'm open to making friends from...                Yes  ...
# 18  No preference, I'm open to making friends from...                Yes  ...
# 19  Students from specific regions or subcontinent...                Yes  ...
# 20  No preference, I'm open to making friends from...                Yes  ...
# 21  No preference, I'm open to making friends from...                 No  ...
# 22  No preference, I'm open to making friends from...                Yes  ...
# 23  No preference, I'm open to making friends from...                Yes  ...
# 24  No preference, I'm open to making friends from...                Yes  ...
# 25  No preference, I'm open to making friends from...                Yes  ...
# 26  No preference, I'm open to making friends from...                Yes  ...
# 27  No preference, I'm open to making friends from...                Yes  ...
# 28  No preference, I'm open to making friends from...                Yes  ...
# 29  No preference, I'm open to making friends from...                Yes  ...
# 30  No preference, I'm open to making friends from...                Yes  ...
# 31    Students from various international backgrounds                Yes  ...
# 32    Students from various international backgrounds                Yes  ...
# 33    Students from various international backgrounds                Yes  ...
# 34          Students from my own country or community                Yes  ...
# 35  No preference, I'm open to making friends from...                Yes  ...
# 36    Students from various international backgrounds                Yes  ...
# 37          Students from my own country or community                Yes  ...
# 38    Students from various international backgrounds                Yes  ...
# 39    Students from various international backgrounds                Yes  ...
# 40    Students from various international backgrounds                Yes  ...
# 41    Students from various international backgrounds                Yes  ...
# 42    Students from various international backgrounds                Yes  ...
# 43    Students from various international backgrounds                Yes  ...
# 44          Students from my own country or community                 No  ...
# 45          Students from my own country or community                 No  ...
# 46    Students from various international backgrounds                 No  ...
# 47    Students from various international backgrounds                Yes  ...
#
#    CulturalAdjustmentChallenge FinancialStressFrequency  \
# 0       Not challenging at all                   Always
# 1         Slightly challenging                Sometimes
# 2       Moderately challenging                   Always
# 3       Moderately challenging                Sometimes
# 4       Moderately challenging                   Always
# 5       Moderately challenging                   Rarely
# 6         Slightly challenging                Sometimes
# 7         Slightly challenging                    Never
# 8         Slightly challenging                   Always
# 9       Moderately challenging                Sometimes
# 10        Slightly challenging                Sometimes
# 11        Slightly challenging                   Always
# 12      Moderately challenging                   Rarely
# 13      Moderately challenging                Sometimes
# 14        Slightly challenging                   Rarely
# 15        Slightly challenging                Sometimes
# 16        Slightly challenging                Sometimes
# 17      Moderately challenging                Sometimes
# 18      Moderately challenging                Sometimes
# 19      Moderately challenging                   Always
# 20        Slightly challenging                   Always
# 21      Not challenging at all                   Always
# 22        Slightly challenging                   Always
# 23      Not challenging at all                   Rarely
# 24      Moderately challenging                Sometimes
# 25      Moderately challenging                   Always
# 26      Moderately challenging                Sometimes
# 27      Moderately challenging                   Always
# 28      Moderately challenging                   Always
# 29        Slightly challenging                   Always
# 30      Moderately challenging                Sometimes
# 31       Extremely challenging                Sometimes
# 32      Moderately challenging                   Always
# 33        Slightly challenging                   Always
# 34        Slightly challenging                   Always
# 35        Slightly challenging                   Always
# 36      Not challenging at all                   Always
# 37      Moderately challenging                   Rarely
# 38      Moderately challenging                   Always
# 39       Extremely challenging                Sometimes
# 40      Not challenging at all                   Rarely
# 41       Extremely challenging                   Always
# 42       Extremely challenging                   Always
# 43        Slightly challenging                Sometimes
# 44      Moderately challenging                   Always
# 45        Slightly challenging                   Rarely
# 46        Slightly challenging                   Rarely
# 47      Moderately challenging                Sometimes
#
#                             WorkStudyBalance     TuitionFeeConcern  \
# 0                     Moderately challenging    Slightly concerned
# 1   Not applicable (I do not work part-time)  Moderately concerned
# 2                       Slightly challenging   Extremely concerned
# 3   Not applicable (I do not work part-time)   Extremely concerned
# 4   Not applicable (I do not work part-time)    Slightly concerned
# 5   Not applicable (I do not work part-time)  Not concerned at all
# 6   Not applicable (I do not work part-time)  Not concerned at all
# 7                       Slightly challenging  Not concerned at all
# 8                      Extremely challenging   Extremely concerned
# 9                     Not challenging at all    Slightly concerned
# 10                    Moderately challenging   Extremely concerned
# 11                      Slightly challenging   Extremely concerned
# 12  Not applicable (I do not work part-time)  Not concerned at all
# 13  Not applicable (I do not work part-time)  Moderately concerned
# 14  Not applicable (I do not work part-time)  Not concerned at all
# 15                    Moderately challenging   Extremely concerned
# 16                    Moderately challenging    Slightly concerned
# 17                      Slightly challenging  Moderately concerned
# 18  Not applicable (I do not work part-time)  Moderately concerned
# 19                    Moderately challenging   Extremely concerned
# 20                      Slightly challenging   Extremely concerned
# 21                     Extremely challenging   Extremely concerned
# 22                     Extremely challenging   Extremely concerned
# 23                      Slightly challenging  Not concerned at all
# 24                    Moderately challenging  Moderately concerned
# 25                    Moderately challenging   Extremely concerned
# 26                      Slightly challenging    Slightly concerned
# 27  Not applicable (I do not work part-time)   Extremely concerned
# 28                    Moderately challenging   Extremely concerned
# 29                    Moderately challenging    Slightly concerned
# 30                    Moderately challenging   Extremely concerned
# 31  Not applicable (I do not work part-time)  Not concerned at all
# 32                     Extremely challenging   Extremely concerned
# 33  Not applicable (I do not work part-time)   Extremely concerned
# 34                     Extremely challenging    Slightly concerned
# 35                     Extremely challenging   Extremely concerned
# 36                      Slightly challenging  Moderately concerned
# 37                    Moderately challenging    Slightly concerned
# 38                     Extremely challenging   Extremely concerned
# 39                    Moderately challenging    Slightly concerned
# 40                      Slightly challenging    Slightly concerned
# 41                    Moderately challenging   Extremely concerned
# 42                     Extremely challenging   Extremely concerned
# 43                     Extremely challenging  Moderately concerned
# 44                    Moderately challenging  Moderately concerned
# 45                    Moderately challenging  Not concerned at all
# 46                    Not challenging at all    Slightly concerned
# 47                    Moderately challenging  Not concerned at all
#
#    FinancialSupportSatisfaction FinancialWorriesImpact   \
# 0                     Satisfied                Slightly
# 1                       Neutral                 Neutral
# 2                   Unsatisfied                 Greatly
# 3                   Unsatisfied                 Greatly
# 4                   Unsatisfied                Slightly
# 5                       Neutral              Not at all
# 6                       Neutral                 Greatly
# 7                     Satisfied              Not at all
# 8                   Unsatisfied                 Greatly
# 9                       Neutral                Slightly
# 10                    Satisfied                 Neutral
# 11                      Neutral                Slightly
# 12                      Neutral                Slightly
# 13                      Neutral                 Greatly
# 14                      Neutral                Slightly
# 15                      Neutral                 Greatly
# 16                    Satisfied                Slightly
# 17                  Unsatisfied                 Neutral
# 18                  Unsatisfied                 Greatly
# 19                  Unsatisfied                 Greatly
# 20                      Neutral                Slightly
# 21                  Unsatisfied                 Greatly
# 22                      Neutral                 Greatly
# 23                      Neutral              Not at all
# 24                    Satisfied                Slightly
# 25                  Unsatisfied                 Greatly
# 26                      Neutral                 Greatly
# 27                  Unsatisfied                Slightly
# 28                      Neutral                 Greatly
# 29                    Satisfied                 Neutral
# 30                    Satisfied                 Neutral
# 31                      Neutral                 Greatly
# 32                  Unsatisfied                 Greatly
# 33                      Neutral                 Neutral
# 34                  Unsatisfied                 Greatly
# 35                  Unsatisfied                 Greatly
# 36                      Neutral                 Greatly
# 37                    Satisfied                 Neutral
# 38                  Unsatisfied                 Greatly
# 39                    Satisfied                 Neutral
# 40                      Neutral                Slightly
# 41                  Unsatisfied                 Greatly
# 42                  Unsatisfied                 Greatly
# 43                  Unsatisfied                Slightly
# 44                  Unsatisfied                 Greatly
# 45                  Unsatisfied                 Greatly
# 46                    Satisfied                 Neutral
# 47                  Unsatisfied                Slightly
#
#    ConsideredTransferring    ReasonsForTransferring  \
# 0                      No         Research Pressure
# 1                     Yes         Financial reasons
# 2                     Yes         Financial reasons
# 3                      No  Academic dissatisfaction
# 4                      No                      None
# 5                      No     Better opportunities
# 6                      No  Academic dissatisfaction
# 7                     Yes         Research Pressure
# 8     Already transferred         Financial reasons
# 9                      No       Social difficulties
# 10                    Yes      Better opportunities
# 11                     No         Financial reasons
# 12                     No                      None
# 13                    Yes          Personal reasons
# 14                    Yes      Better opportunities
# 15                    Yes      Better opportunities
# 16                    Yes          Personal reasons
# 17                    Yes       Social difficulties
# 18                     No         Financial reasons
# 19                    Yes         Financial reasons
# 20                    Yes         Financial reasons
# 21                    Yes         Financial reasons
# 22                    Yes         Financial reasons
# 23                     No          Personal reasons
# 24                     No      Better opportunities
# 25                    Yes         Financial reasons
# 26                    Yes         Financial reasons
# 27                     No         Financial reasons
# 28    Already transferred         Financial reasons
# 29                     No         Research Pressure
# 30                    Yes      Better opportunities
# 31                     No      Better opportunities
# 32    Already transferred         Financial reasons
# 33                    Yes         Financial reasons
# 34                     No      Better opportunities
# 35                    Yes         Research Pressure
# 36    Already transferred         Financial reasons
# 37                     No         Research Pressure
# 38    Already transferred  Academic dissatisfaction
# 39                    Yes         Research Pressure
# 40                     No  Academic dissatisfaction
# 41                    Yes  Academic dissatisfaction
# 42                    Yes         Financial reasons
# 43                    Yes      Better opportunities
# 44                    Yes      Better opportunities
# 45                    Yes      Better opportunities
# 46                     No          Personal reasons
# 47                    Yes      Better opportunities
#
#                                           StayFactors AcademicExperienceRating
# 0   Improved academic experience, Financial suppor...                     Good
# 1   Improved academic experience, Stronger social ...                     Good
# 2                  Adaptation to cultural environment                     Good
# 3                        Improved academic experience                  Average
# 4                      Financial support/scholarships                     Good
# 5                  Adaptation to cultural environment                     Good
# 6                  Adaptation to cultural environment                     Poor
# 7                      Financial support/scholarships                     Good
# 8                      Financial support/scholarships                     Poor
# 9                        Improved academic experience                  Average
# 10                       Improved academic experience                     Good
# 11  Improved academic experience, Stronger social ...                Excellent
# 12                       Improved academic experience                     Good
# 13  Improved academic experience, Financial suppor...                  Average
# 14                 Adaptation to cultural environment                     Good
# 15                     Financial support/scholarships                  Average
# 16  Financial support/scholarships, Stronger socia...                     Good
# 17  Improved academic experience, Financial suppor...                     Good
# 18                 Adaptation to cultural environment                  Average
# 19                        Stronger social connections                     Poor
# 20                       Improved academic experience                  Average
# 21                                            Nothing                     Poor
# 22                     Financial support/scholarships                  Average
# 23                       Improved academic experience                Excellent
# 24                       Improved academic experience                     Good
# 25  Improved academic experience, Adaptation to cu...                     Good
# 26                       Improved academic experience                  Average
# 27  Stronger social connections, Adaptation to cul...                  Average
# 28                     Financial support/scholarships                     Good
# 29  Improved academic experience, Financial suppor...                     Good
# 30  Financial support/scholarships, Stronger socia...                     Good
# 31                     Financial support/scholarships                Excellent
# 32  Improved academic experience, Financial suppor...                     Poor
# 33  Stronger social connections, Adaptation to cul...                     Good
# 34                        Stronger social connections                  Average
# 35  Improved academic experience, Adaptation to cu...                  Average
# 36                     Financial support/scholarships                Excellent
# 37  Improved academic experience, Financial suppor...                     Good
# 38  Improved academic experience, Financial suppor...                     Poor
# 39  Improved academic experience, Financial suppor...                  Average
# 40                       Improved academic experience                     Good
# 41  Improved academic experience, Financial suppor...                     Poor
# 42  Improved academic experience, Financial suppor...                     Poor
# 43  Improved academic experience, Financial suppor...                Excellent
# 44                     Financial support/scholarships                     Good
# 45                     Financial support/scholarships                  Average
# 46  Improved academic experience, Financial suppor...                Excellent
# 47  Financial support/scholarships, Adaptation to ...                     Good
#
# [48 rows x 28 columns]

# %%
query = '''SELECT * FROM Students
        WHERE (HomeRegion = 'South Asia') OR (CampusParticipation = 'Sometimes')
        '''
db = pd.read_sql_query(sql = query, con = engine)
db
# Out:
#      LevelOfStudy                         StudyDurationUI   \
# 0        Graduate                             1 to 2 years
# 1   Undergraduate                       Less than 6 months
# 2        Graduate                             2 to 3 years
# 3        Graduate                        More than 3 years
# 4       Graduated                                Graduated
# 5        Graduate                             1 to 2 years
# 6        Graduate                             1 to 2 years
# 7   Undergraduate                       Less than 6 months
# 8        Graduate                       6 months to 1 year
# 9   Undergraduate                       Less than 6 months
# 10       Graduate                       Less than 6 months
# 11       Graduate                       6 months to 1 year
# 12       Graduate                             2 to 3 years
# 13  Undergraduate                       Less than 6 months
# 14       Graduate                             1 to 2 years
# 15  Undergraduate                             1 to 2 years
# 16       Graduate                        More than 3 years
# 17  Undergraduate                             1 to 2 years
# 18  Undergraduate                             1 to 2 years
# 19  Undergraduate                             1 to 2 years
# 20  Undergraduate                             1 to 2 years
# 21  Undergraduate                       6 months to 1 year
# 22       Graduate                             1 to 2 years
# 23  Undergraduate                             2 to 3 years
# 24  Undergraduate                       Less than 6 months
# 25  Undergraduate                       Less than 6 months
# 26  Undergraduate  Transfer (Uidaho to Another University)
# 27       Graduate                             1 to 2 years
# 28  Undergraduate                       Less than 6 months
# 29       Graduate                             1 to 2 years
# 30  Undergraduate  Transfer (Uidaho to Another University)
# 31  Undergraduate                       Less than 6 months
# 32       Graduate                       6 months to 1 year
# 33  Undergraduate                       6 months to 1 year
# 34       Graduate                             2 to 3 years
# 35       Graduate                             1 to 2 years
# 36  Undergraduate                             1 to 2 years
# 37  Undergraduate                       6 months to 1 year
# 38  Undergraduate                       Less than 6 months
# 39       Graduate                             2 to 3 years
#
#             HomeRegion         CGPA  \
# 0           South Asia  3.50 - 4.00
# 1           South Asia  3.50 - 4.00
# 2           South Asia  3.50 - 4.00
# 3           South Asia  3.00 - 3.49
# 4           South Asia  3.50 - 4.00
# 5           South Asia  3.50 - 4.00
# 6           South Asia  3.50 - 4.00
# 7           South Asia  3.50 - 4.00
# 8       Southeast Asia  3.50 - 4.00
# 9           South Asia  3.00 - 3.49
# 10          South Asia  3.50 - 4.00
# 11          South Asia  3.50 - 4.00
# 12           East Asia  3.00 - 3.49
# 13          South Asia  3.50 - 4.00
# 14          South Asia  3.50 - 4.00
# 15      Southeast Asia  3.00 - 3.49
# 16          South Asia  3.50 - 4.00
# 17      Southeast Asia  3.00 - 3.49
# 18          South Asia  3.00 - 3.49
# 19          South Asia  2.50 - 2.99
# 20          South Asia   2.0 - 2.49
# 21          South Asia  3.00 - 3.49
# 22          South Asia  3.50 - 4.00
# 23          South Asia  3.50 - 4.00
# 24          South Asia  3.50 - 4.00
# 25           East Asia    Below 1.0
# 26          South Asia  3.00 - 3.49
# 27          South Asia  3.50 - 4.00
# 28          South Asia  3.50 - 4.00
# 29           East Asia  3.50 - 4.00
# 30          South Asia  2.50 - 2.99
# 31          South Asia  3.50 - 4.00
# 32          South Asia  3.00 - 3.49
# 33          South Asia   2.0 - 2.49
# 34           East Asia  3.50 - 4.00
# 35  Sub-Saharan Africa  3.50 - 4.00
# 36              Europe  3.50 - 4.00
# 37  Sub-Saharan Africa  2.50 - 2.99
# 38              Europe  3.50 - 4.00
# 39        Central Asia  3.00 - 3.49
#
#                                         FundingSource CampusParticipation  \
# 0                                           GRA / GTA               Often
# 1                         Family support, Scholarship               Often
# 2                                           GRA / GTA           Sometimes
# 3                                           GRA / GTA           Sometimes
# 4                                           GRA / GTA           Sometimes
# 5                                           GRA / GTA           Sometimes
# 6                                           GRA / GTA           Sometimes
# 7                                      Family support               Often
# 8                                           GRA / GTA           Sometimes
# 9                    Personal savings, Family support              Always
# 10                                          GRA / GTA           Sometimes
# 11                                          GRA / GTA           Sometimes
# 12                                          GRA / GTA           Sometimes
# 13                                     Family support              Always
# 14                                          GRA / GTA           Sometimes
# 15             Scholarship, Part-time job (On-campus)           Sometimes
# 16                                          GRA / GTA               Often
# 17                        Family support, Scholarship           Sometimes
# 18          Family support, Part-time job (On-campus)           Sometimes
# 19          Family support, Part-time job (On-campus)               Never
# 20  Personal savings, Scholarship, Part-time job (...              Always
# 21                        Family support, Scholarship           Sometimes
# 22                                          GRA / GTA           Sometimes
# 23          Family support, Part-time job (On-campus)              Always
# 24                                     Family support               Often
# 25      Personal savings, Family support, Scholarship           Sometimes
# 26  Family support, Scholarship, Part-time job (On...              Always
# 27                                          GRA / GTA               Often
# 28  Family support, Scholarship, Part-time job (On...               Often
# 29                                          GRA / GTA           Sometimes
# 30          Family support, Part-time job (On-campus)               Often
# 31                        Family support, Scholarship           Sometimes
# 32                                          GRA / GTA               Never
# 33  Family support, Scholarship, Part-time job (On...               Often
# 34                                          GRA / GTA           Sometimes
# 35                                          GRA / GTA           Sometimes
# 36  Personal savings, Family support, Scholarship,...           Sometimes
# 37  Personal savings, Scholarship, Part-time job (...           Sometimes
# 38          Family support, Part-time job (On-campus)           Sometimes
# 39                                          GRA / GTA           Sometimes
#
#    FriendshipEase                                 FriendsComposition  \
# 0        Moderate  Mostly students from my subcontinent but diffe...
# 1        Moderate                             A mix of all the above
# 2            Easy                             A mix of all the above
# 3        Moderate  Mostly students from my subcontinent but diffe...
# 4        Moderate  Mostly international students from various cou...
# 5        Moderate      Mostly students from my own community/country
# 6        Moderate  Mostly students from my subcontinent but diffe...
# 7        Moderate  Mostly students from my subcontinent but diffe...
# 8        Moderate                             A mix of all the above
# 9            Easy                             A mix of all the above
# 10       Moderate      Mostly students from my own community/country
# 11       Moderate      Mostly students from my own community/country
# 12       Moderate                             A mix of all the above
# 13       Moderate  Mostly international students from various cou...
# 14       Moderate  Mostly students from my subcontinent but diffe...
# 15       Moderate      Mostly students from my own community/country
# 16       Moderate  Mostly students from my subcontinent but diffe...
# 17       Moderate      Mostly students from my own community/country
# 18           Easy                             A mix of all the above
# 19      Difficult      Mostly students from my own community/country
# 20       Moderate                             A mix of all the above
# 21       Moderate  Mostly students from my subcontinent but diffe...
# 22       Moderate                             A mix of all the above
# 23      Difficult                             A mix of all the above
# 24           Easy                             A mix of all the above
# 25       Moderate      Mostly students from my own community/country
# 26           Easy                             A mix of all the above
# 27       Moderate  Mostly students from my subcontinent but diffe...
# 28       Moderate                             A mix of all the above
# 29      Difficult      Mostly students from my own community/country
# 30           Easy  Mostly students from my subcontinent but diffe...
# 31       Moderate      Mostly students from my own community/country
# 32       Moderate      Mostly students from my own community/country
# 33           Easy  Mostly students from my subcontinent but diffe...
# 34       Moderate      Mostly students from my own community/country
# 35      Difficult      Mostly students from my own community/country
# 36       Moderate  Mostly international students from various cou...
# 37      Difficult      Mostly students from my own community/country
# 38       Moderate  Mostly international students from various cou...
# 39       Moderate      Mostly students from my own community/country
#
#                                  FriendshipPreference InterestNewFriends  ...  \
# 0   No preference, I'm open to making friends from...                Yes  ...
# 1     Students from various international backgrounds                Yes  ...
# 2   No preference, I'm open to making friends from...                Yes  ...
# 3     Students from various international backgrounds                Yes  ...
# 4   No preference, I'm open to making friends from...                Yes  ...
# 5     Students from various international backgrounds                Yes  ...
# 6   No preference, I'm open to making friends from...                 No  ...
# 7     Students from various international backgrounds                Yes  ...
# 8   No preference, I'm open to making friends from...                Yes  ...
# 9   No preference, I'm open to making friends from...                Yes  ...
# 10    Students from various international backgrounds                Yes  ...
# 11  No preference, I'm open to making friends from...                Yes  ...
# 12  No preference, I'm open to making friends from...                 No  ...
# 13  No preference, I'm open to making friends from...                Yes  ...
# 14  No preference, I'm open to making friends from...                Yes  ...
# 15  No preference, I'm open to making friends from...                Yes  ...
# 16  No preference, I'm open to making friends from...                Yes  ...
# 17  Students from specific regions or subcontinent...                Yes  ...
# 18  No preference, I'm open to making friends from...                Yes  ...
# 19  No preference, I'm open to making friends from...                 No  ...
# 20  No preference, I'm open to making friends from...                Yes  ...
# 21  No preference, I'm open to making friends from...                Yes  ...
# 22  No preference, I'm open to making friends from...                Yes  ...
# 23  No preference, I'm open to making friends from...                Yes  ...
# 24  No preference, I'm open to making friends from...                Yes  ...
# 25  No preference, I'm open to making friends from...                Yes  ...
# 26  No preference, I'm open to making friends from...                Yes  ...
# 27  No preference, I'm open to making friends from...                Yes  ...
# 28  No preference, I'm open to making friends from...                Yes  ...
# 29    Students from various international backgrounds                Yes  ...
# 30    Students from various international backgrounds                Yes  ...
# 31    Students from various international backgrounds                Yes  ...
# 32          Students from my own country or community                Yes  ...
# 33    Students from various international backgrounds                Yes  ...
# 34          Students from my own country or community                Yes  ...
# 35    Students from various international backgrounds                Yes  ...
# 36    Students from various international backgrounds                Yes  ...
# 37    Students from various international backgrounds                Yes  ...
# 38    Students from various international backgrounds                Yes  ...
# 39    Students from various international backgrounds                Yes  ...
#
#    CulturalAdjustmentChallenge FinancialStressFrequency  \
# 0       Not challenging at all                   Always
# 1         Slightly challenging                Sometimes
# 2       Moderately challenging                Sometimes
# 3       Moderately challenging                   Always
# 4       Moderately challenging                   Rarely
# 5         Slightly challenging                Sometimes
# 6         Slightly challenging                    Never
# 7       Moderately challenging                Sometimes
# 8         Slightly challenging                Sometimes
# 9         Slightly challenging                   Always
# 10      Moderately challenging                   Rarely
# 11      Moderately challenging                Sometimes
# 12        Slightly challenging                   Rarely
# 13        Slightly challenging                Sometimes
# 14        Slightly challenging                Sometimes
# 15      Moderately challenging                Sometimes
# 16      Moderately challenging                Sometimes
# 17      Moderately challenging                   Always
# 18        Slightly challenging                   Always
# 19      Not challenging at all                   Always
# 20        Slightly challenging                   Always
# 21      Not challenging at all                   Rarely
# 22      Moderately challenging                Sometimes
# 23      Moderately challenging                   Always
# 24      Moderately challenging                Sometimes
# 25      Moderately challenging                   Always
# 26      Moderately challenging                   Always
# 27        Slightly challenging                   Always
# 28      Moderately challenging                Sometimes
# 29       Extremely challenging                Sometimes
# 30      Moderately challenging                   Always
# 31        Slightly challenging                   Always
# 32        Slightly challenging                   Always
# 33      Not challenging at all                   Always
# 34      Moderately challenging                   Rarely
# 35       Extremely challenging                Sometimes
# 36      Not challenging at all                   Rarely
# 37       Extremely challenging                   Always
# 38        Slightly challenging                Sometimes
# 39      Moderately challenging                Sometimes
#
#                             WorkStudyBalance     TuitionFeeConcern  \
# 0                     Moderately challenging    Slightly concerned
# 1   Not applicable (I do not work part-time)  Moderately concerned
# 2   Not applicable (I do not work part-time)   Extremely concerned
# 3   Not applicable (I do not work part-time)    Slightly concerned
# 4   Not applicable (I do not work part-time)  Not concerned at all
# 5   Not applicable (I do not work part-time)  Not concerned at all
# 6                       Slightly challenging  Not concerned at all
# 7                     Not challenging at all    Slightly concerned
# 8                     Moderately challenging   Extremely concerned
# 9                       Slightly challenging   Extremely concerned
# 10  Not applicable (I do not work part-time)  Not concerned at all
# 11  Not applicable (I do not work part-time)  Moderately concerned
# 12  Not applicable (I do not work part-time)  Not concerned at all
# 13                    Moderately challenging   Extremely concerned
# 14                    Moderately challenging    Slightly concerned
# 15                      Slightly challenging  Moderately concerned
# 16  Not applicable (I do not work part-time)  Moderately concerned
# 17                    Moderately challenging   Extremely concerned
# 18                      Slightly challenging   Extremely concerned
# 19                     Extremely challenging   Extremely concerned
# 20                     Extremely challenging   Extremely concerned
# 21                      Slightly challenging  Not concerned at all
# 22                    Moderately challenging  Moderately concerned
# 23                    Moderately challenging   Extremely concerned
# 24                      Slightly challenging    Slightly concerned
# 25  Not applicable (I do not work part-time)   Extremely concerned
# 26                    Moderately challenging   Extremely concerned
# 27                    Moderately challenging    Slightly concerned
# 28                    Moderately challenging   Extremely concerned
# 29  Not applicable (I do not work part-time)  Not concerned at all
# 30                     Extremely challenging   Extremely concerned
# 31  Not applicable (I do not work part-time)   Extremely concerned
# 32                     Extremely challenging    Slightly concerned
# 33                      Slightly challenging  Moderately concerned
# 34                    Moderately challenging    Slightly concerned
# 35                    Moderately challenging    Slightly concerned
# 36                      Slightly challenging    Slightly concerned
# 37                     Extremely challenging   Extremely concerned
# 38                     Extremely challenging  Moderately concerned
# 39                    Moderately challenging  Not concerned at all
#
#    FinancialSupportSatisfaction FinancialWorriesImpact   \
# 0                     Satisfied                Slightly
# 1                       Neutral                 Neutral
# 2                   Unsatisfied                 Greatly
# 3                   Unsatisfied                Slightly
# 4                       Neutral              Not at all
# 5                       Neutral                 Greatly
# 6                     Satisfied              Not at all
# 7                       Neutral                Slightly
# 8                     Satisfied                 Neutral
# 9                       Neutral                Slightly
# 10                      Neutral                Slightly
# 11                      Neutral                 Greatly
# 12                      Neutral                Slightly
# 13                      Neutral                 Greatly
# 14                    Satisfied                Slightly
# 15                  Unsatisfied                 Neutral
# 16                  Unsatisfied                 Greatly
# 17                  Unsatisfied                 Greatly
# 18                      Neutral                Slightly
# 19                  Unsatisfied                 Greatly
# 20                      Neutral                 Greatly
# 21                      Neutral              Not at all
# 22                    Satisfied                Slightly
# 23                  Unsatisfied                 Greatly
# 24                      Neutral                 Greatly
# 25                  Unsatisfied                Slightly
# 26                      Neutral                 Greatly
# 27                    Satisfied                 Neutral
# 28                    Satisfied                 Neutral
# 29                      Neutral                 Greatly
# 30                  Unsatisfied                 Greatly
# 31                      Neutral                 Neutral
# 32                  Unsatisfied                 Greatly
# 33                      Neutral                 Greatly
# 34                    Satisfied                 Neutral
# 35                    Satisfied                 Neutral
# 36                      Neutral                Slightly
# 37                  Unsatisfied                 Greatly
# 38                  Unsatisfied                Slightly
# 39                  Unsatisfied                Slightly
#
#    ConsideredTransferring    ReasonsForTransferring  \
# 0                      No         Research Pressure
# 1                     Yes         Financial reasons
# 2                      No  Academic dissatisfaction
# 3                      No                      None
# 4                      No     Better opportunities
# 5                      No  Academic dissatisfaction
# 6                     Yes         Research Pressure
# 7                      No       Social difficulties
# 8                     Yes      Better opportunities
# 9                      No         Financial reasons
# 10                     No                      None
# 11                    Yes          Personal reasons
# 12                    Yes      Better opportunities
# 13                    Yes      Better opportunities
# 14                    Yes          Personal reasons
# 15                    Yes       Social difficulties
# 16                     No         Financial reasons
# 17                    Yes         Financial reasons
# 18                    Yes         Financial reasons
# 19                    Yes         Financial reasons
# 20                    Yes         Financial reasons
# 21                     No          Personal reasons
# 22                     No      Better opportunities
# 23                    Yes         Financial reasons
# 24                    Yes         Financial reasons
# 25                     No         Financial reasons
# 26    Already transferred         Financial reasons
# 27                     No         Research Pressure
# 28                    Yes      Better opportunities
# 29                     No      Better opportunities
# 30    Already transferred         Financial reasons
# 31                    Yes         Financial reasons
# 32                     No      Better opportunities
# 33    Already transferred         Financial reasons
# 34                     No         Research Pressure
# 35                    Yes         Research Pressure
# 36                     No  Academic dissatisfaction
# 37                    Yes         Financial reasons
# 38                    Yes      Better opportunities
# 39                    Yes      Better opportunities
#
#                                           StayFactors AcademicExperienceRating
# 0   Improved academic experience, Financial suppor...                     Good
# 1   Improved academic experience, Stronger social ...                     Good
# 2                        Improved academic experience                  Average
# 3                      Financial support/scholarships                     Good
# 4                  Adaptation to cultural environment                     Good
# 5                  Adaptation to cultural environment                     Poor
# 6                      Financial support/scholarships                     Good
# 7                        Improved academic experience                  Average
# 8                        Improved academic experience                     Good
# 9   Improved academic experience, Stronger social ...                Excellent
# 10                       Improved academic experience                     Good
# 11  Improved academic experience, Financial suppor...                  Average
# 12                 Adaptation to cultural environment                     Good
# 13                     Financial support/scholarships                  Average
# 14  Financial support/scholarships, Stronger socia...                     Good
# 15  Improved academic experience, Financial suppor...                     Good
# 16                 Adaptation to cultural environment                  Average
# 17                        Stronger social connections                     Poor
# 18                       Improved academic experience                  Average
# 19                                            Nothing                     Poor
# 20                     Financial support/scholarships                  Average
# 21                       Improved academic experience                Excellent
# 22                       Improved academic experience                     Good
# 23  Improved academic experience, Adaptation to cu...                     Good
# 24                       Improved academic experience                  Average
# 25  Stronger social connections, Adaptation to cul...                  Average
# 26                     Financial support/scholarships                     Good
# 27  Improved academic experience, Financial suppor...                     Good
# 28  Financial support/scholarships, Stronger socia...                     Good
# 29                     Financial support/scholarships                Excellent
# 30  Improved academic experience, Financial suppor...                     Poor
# 31  Stronger social connections, Adaptation to cul...                     Good
# 32                        Stronger social connections                  Average
# 33                     Financial support/scholarships                Excellent
# 34  Improved academic experience, Financial suppor...                     Good
# 35  Improved academic experience, Financial suppor...                  Average
# 36                       Improved academic experience                     Good
# 37  Improved academic experience, Financial suppor...                     Poor
# 38  Improved academic experience, Financial suppor...                Excellent
# 39  Financial support/scholarships, Adaptation to ...                     Good
#
# [40 rows x 28 columns]

# %%
query = '''SELECT COUNT(*) FROM Students
        WHERE HomeRegion = 'South Asia'
        '''
db = pd.read_sql_query(sql = query, con = engine)
db
# Out:
#    COUNT(*)
# 0        28

# %% [markdown]
# Оператор GROUP BY используется для определения групп выходных строк, к которым могут применяться агрегатные функции (COUNT, MIN, MAX, AVG и SUM). Группировка данных позволяет объединить одинаковые значения в заданных полях в группы, а затем выполнять подсчеты для каждой группы. Если в результате выполнения запроса не получено ни одной строки (или ни одной строки для данной группы), то исходные данные для вычисления любой из агрегатных функций отсутствуют. В этом случае результатом выполнения функций COUNT будет нуль, а результатом всех других функций — NULL.
#
# Агрегатные функции **MIN** и **MAX** вычисляют наименьшее и наибольшее значение столбца соответственно. Аргументами могут быть числа, строки и даты. Все значения NULL удаляются перед вычислением (т.е. в расчет не берутся).
#
# Агрегатная функция **SUM** вычисляет общую сумму значений столбца. Аргументами могут быть только числа. Использование параметра DISTINCT устраняет все повторяющиеся значения в столбце перед применением функции SUM. Аналогично удаляются все значения NULL перед применением этой агрегатной функции.
#
# Агрегатная функция **AVG** возвращает среднее значение для всех значений столбца. Аргументами также могут быть только числа, а все значения NULL удаляются перед вычислением.
#
# Агрегатная функция **COUNT** имеет две разные формы:
#
# **COUNT([DISTINCT] col_name)** — подсчитывает количество значений в столбце col_name, значения NULL не учитываются
#
# **COUNT(*)** — подсчитывает количество строк в таблице, значения NULL также учитываются
#
#
# Для GROUP BY все значения NULL трактуются как равные, т.е. при группировке по полю, содержащему NULL-значения, все такие строки попадут в одну группу.
#
# Чтобы присвоить столбцу псевдоним, нужно после его определения записать AS и указать желаемое имя. Оно должно начинаться с буквы и не должно содержать пробелов.

# %%
query = '''SELECT CGPA, COUNT(*) as South_Asia_stud_num FROM Students
        WHERE HomeRegion = 'South Asia'
        GROUP BY CGPA'''
db = pd.read_sql_query(sql = query, con = engine)
db
# Out:
#           CGPA  South_Asia_stud_num
# 0   2.0 - 2.49                    2
# 1  2.50 - 2.99                    2
# 2  3.00 - 3.49                    6
# 3  3.50 - 4.00                   18

# %%
query = '''SELECT CGPA, COUNT(*) as South_Asia_stud_num FROM Students
        WHERE HomeRegion = 'South Asia'
        GROUP BY CGPA
        ORDER BY South_Asia_stud_num
        '''
db = pd.read_sql_query(sql = query, con = engine)
db
# Out:
#           CGPA  South_Asia_stud_num
# 0   2.0 - 2.49                    2
# 1  2.50 - 2.99                    2
# 2  3.00 - 3.49                    6
# 3  3.50 - 4.00                   18

# %%
query = '''SELECT CGPA, COUNT(*) as South_Asia_stud_num FROM Students
        WHERE HomeRegion = 'South Asia'
        GROUP BY CGPA
        ORDER BY South_Asia_stud_num DESC
        '''
db = pd.read_sql_query(sql = query, con = engine)
db
# Out:
#           CGPA  South_Asia_stud_num
# 0  3.50 - 4.00                   18
# 1  3.00 - 3.49                    6
# 2  2.50 - 2.99                    2
# 3   2.0 - 2.49                    2

# %% [markdown]
# В предложении HAVING определяется условие, которое применяется к группе строк. Оно имеет такой же смысл для групп строк, что и предложение WHERE для содержимого соответствующей таблицы (WHERE применяется до группировки, HAVING после):

# %%
query = '''SELECT CGPA, COUNT(*) as South_Asia_stud_num FROM Students
        WHERE HomeRegion = 'South Asia'
        GROUP BY CGPA
        HAVING South_Asia_stud_num > 2
        '''
db = pd.read_sql_query(sql = query, con = engine)
db
# Out:
#           CGPA  South_Asia_stud_num
# 0  3.00 - 3.49                    6
# 1  3.50 - 4.00                   18

# %% [markdown]
# Дополнительно попрактиковаться с запросами можно в тренажёре: https://www.w3schools.com/sql/

# %% [markdown]
# ## Практические задания

# %% [markdown]
# 1. Загрузите и проанализируйте данные из датасета: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce?select=olist_products_dataset.csv

# %% [markdown]
# 2. Выполните предобработку данных (проверка пропусков, дубликатов и т. д.).

# %% [markdown]
# 3. Используя предобработанные в предыдущем пункте данные создайте базу данных под названием 'Brazilian_sales' и заполните её таблицами.

# %% [markdown]
# 4. С помощью SQL-запроса подсчитайте число уникальных пользователей и число уникальных пользователей по странам.

# %% [markdown]
# 5. Определите сумму заказов за весь рассматриваемый период по каждому клиенту.

# %% [markdown]
# 6. Какие категории товаров клиенты предпочитают покупать в Sao Paulo, а какие в Rio De Janeiro?

# %% [markdown]
# 7. В какое время и пользователем с каким id был совершён заказ на максимальную за рассматриваемый период сумму?

# %% [markdown]
# 8. Проанализируйте динамику продаж товаров (по сумме заказав) в разрезе дней.

# %% [markdown]
# 9. Вычислите суммарную выручку и число заказов в разрезе типов оплаты (поле payment_type).

# %% [markdown]
# 10. Определите среднию оценку (поле review_score) для заказов в зависимости от статуса заказа (order_status).
